# %% [markdown]
# <a href="https://colab.research.google.com/github/Aneliukee/Machine-Learning/blob/main/ML_LD1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import math
import matplotlib.pyplot as plt

if __name__ == '__main__':
  x = np.arange(10)
  y = np.array([math.sin(variable) for variable in x])
  plt.plot(x, y)
  plt.show()
